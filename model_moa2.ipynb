# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import jaccard_score, log_loss

import prepare, model

# %% [markdown]
# ### Construct a model to predict MoA annotation cyclooxygenase inhibitor

# %%
# Load X and Y.

X = pd.read_csv('train_features.csv', index_col=0)
Y = pd.read_csv('train_targets_scored.csv', index_col=0)

# Print their shapes
X.shape, Y.shape
# Out:
# ((23814, 875), (23814, 206))

# %%
# Take a peek at X
X.head()
# Out:
#              cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3     g-4  \
# sig_id
# id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208 -0.1944
# id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604  1.0190
# id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764 -0.0323
# id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288  4.0620
# id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919  1.4180
#
#                  g-5     g-6  ...    c-90    c-91    c-92    c-93    c-94  \
# sig_id                        ...
# id_000644bb2 -1.0120 -1.0220  ...  0.2862  0.2584  0.8076  0.5523 -0.1912
# id_000779bfc  0.5207  0.2341  ... -0.4265  0.7543  0.4708  0.0230  0.2957
# id_000a6266a  1.2390  0.1715  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240
# id_0015fd391 -0.8095 -1.9590  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632
# id_001626bd3 -0.8244 -0.2800  ...  0.0042  0.0048  0.6670  1.0690  0.5523
#
#                 c-95    c-96    c-97    c-98    c-99
# sig_id
# id_000644bb2  0.6584 -0.3981  0.2139  0.3801  0.4176
# id_000779bfc  0.4899  0.1522  0.1241  0.6077  0.7371
# id_000a6266a -0.3174 -0.6417 -0.2187 -1.4080  0.6931
# id_0015fd391 -1.2880 -1.6210 -0.8784 -0.3876 -0.8154
# id_001626bd3 -0.3031  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 875 columns]

# %%
# Isolate label cyclooxygenase_inhibitor
y = Y.loc[:, 'cyclooxygenase_inhibitor']

# Take a peek at y
y.head()
# Out:
# sig_id
# id_000644bb2    0
# id_000779bfc    0
# id_000a6266a    0
# id_0015fd391    0
# id_001626bd3    0
# Name: cyclooxygenase_inhibitor, dtype: int64

# %%
# Concat y to X
df = pd.concat([X, y], axis=1)

# Take a peek at df
df.head()
# Out:
#              cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3     g-4  \
# sig_id
# id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208 -0.1944
# id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604  1.0190
# id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764 -0.0323
# id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288  4.0620
# id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919  1.4180
#
#                  g-5     g-6  ...    c-91    c-92    c-93    c-94    c-95  \
# sig_id                        ...
# id_000644bb2 -1.0120 -1.0220  ...  0.2584  0.8076  0.5523 -0.1912  0.6584
# id_000779bfc  0.5207  0.2341  ...  0.7543  0.4708  0.0230  0.2957  0.4899
# id_000a6266a  1.2390  0.1715  ... -0.6297  0.6103  0.0223 -1.3240 -0.3174
# id_0015fd391 -0.8095 -1.9590  ... -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# id_001626bd3 -0.8244 -0.2800  ...  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#                 c-96    c-97    c-98    c-99  cyclooxygenase_inhibitor
# sig_id
# id_000644bb2 -0.3981  0.2139  0.3801  0.4176                         0
# id_000779bfc  0.1522  0.1241  0.6077  0.7371                         0
# id_000a6266a -0.6417 -0.2187 -1.4080  0.6931                         0
# id_0015fd391 -1.6210 -0.8784 -0.3876 -0.8154                         0
# id_001626bd3  0.1094  0.2885 -0.3786  0.7125                         0
#
# [5 rows x 876 columns]

# %%
# Load the .csv file
df = pd.read_csv('classify_cyclooxygenase_inhibitor.csv', index_col=0)
df.head()
# Out:
#              cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3     g-4  \
# sig_id
# id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208 -0.1944
# id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604  1.0190
# id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764 -0.0323
# id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288  4.0620
# id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919  1.4180
#
#                  g-5     g-6  ...    c-91    c-92    c-93    c-94    c-95  \
# sig_id                        ...
# id_000644bb2 -1.0120 -1.0220  ...  0.2584  0.8076  0.5523 -0.1912  0.6584
# id_000779bfc  0.5207  0.2341  ...  0.7543  0.4708  0.0230  0.2957  0.4899
# id_000a6266a  1.2390  0.1715  ... -0.6297  0.6103  0.0223 -1.3240 -0.3174
# id_0015fd391 -0.8095 -1.9590  ... -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# id_001626bd3 -0.8244 -0.2800  ...  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#                 c-96    c-97    c-98    c-99  cyclooxygenase_inhibitor
# sig_id
# id_000644bb2 -0.3981  0.2139  0.3801  0.4176                         0
# id_000779bfc  0.1522  0.1241  0.6077  0.7371                         0
# id_000a6266a -0.6417 -0.2187 -1.4080  0.6931                         0
# id_0015fd391 -1.6210 -0.8784 -0.3876 -0.8154                         0
# id_001626bd3  0.1094  0.2885 -0.3786  0.7125                         0
#
# [5 rows x 876 columns]

# %%
# Data Preparation

scaler, train_scaled, validate_scaled, test_scaled = prepare.classifiy_cyclooxygenase_inhibitor(df)

# Print the scaler and the shape of the data
scaler, train_scaled.shape, validate_scaled.shape, test_scaled.shape
# Out:
# (MinMaxScaler(copy=True, feature_range=(0, 1)),
#  (17145, 877),
#  (4287, 877),
#  (2382, 877))

# %%
# Take a look at train_scaled
train_scaled.head()
# Out:
#               cyclooxygenase_inhibitor  cp_type_trt_cp  cp_time_48  \
# sig_id
# id_848dcc064                         0               1           1
# id_b9ce40651                         0               1           0
# id_a23c124dd                         0               1           0
# id_632f29352                         0               1           0
# id_db60af3c3                         0               1           1
#
#               cp_time_72  cp_dose_D2  g-0_scaled  g-1_scaled  g-2_scaled  \
# sig_id
# id_848dcc064           0           0    0.278145    0.438289    0.514682
# id_b9ce40651           0           0    0.301602    0.460960    0.464432
# id_a23c124dd           0           1    0.351926    0.524016    0.515898
# id_632f29352           0           0    0.331621    0.518773    0.543719
# id_db60af3c3           0           1    0.309449    0.436247    0.496584
#
#               g-3_scaled  g-4_scaled  ...  c-90_scaled  c-91_scaled  \
# sig_id                                ...
# id_848dcc064    0.429166    0.409585  ...     0.752996     0.778936
# id_b9ce40651    0.374016    0.356350  ...     0.727436     0.733129
# id_a23c124dd    0.409870    0.399615  ...     0.752918     0.791095
# id_632f29352    0.407282    0.320056  ...     0.738325     0.794703
# id_db60af3c3    0.438492    0.354072  ...     0.823442     0.733865
#
#               c-92_scaled  c-93_scaled  c-94_scaled  c-95_scaled  c-96_scaled  \
# sig_id
# id_848dcc064     0.714310     0.794292     0.723889     0.851225     0.749730
# id_b9ce40651     0.694349     0.748580     0.764400     0.743710     0.776720
# id_a23c124dd     0.706096     0.776449     0.661817     0.778625     0.821844
# id_632f29352     0.587779     0.808650     0.703848     0.811472     0.791514
# id_db60af3c3     0.788246     0.732076     0.736910     0.825784     0.760141
#
#               c-97_scaled  c-98_scaled  c-99_scaled
# sig_id
# id_848dcc064     0.849285     0.781899     0.784009
# id_b9ce40651     0.833604     0.806951     0.805640
# id_a23c124dd     0.809407     0.714703     0.618445
# id_632f29352     0.774037     0.719991     0.771593
# id_db60af3c3     0.882725     0.826118     0.813803
#
# [5 rows x 877 columns]

# %%
# Create X and y (scaled)

X_train = train_scaled.iloc[:,1:]
X_validate = validate_scaled.iloc[:,1:]
X_test = test_scaled.iloc[:,1:]

y_train = train_scaled.loc[:, 'cyclooxygenase_inhibitor']
y_validate = validate_scaled.loc[:, 'cyclooxygenase_inhibitor']
y_test = test_scaled.loc[:, 'cyclooxygenase_inhibitor']

# %%
# Take a look at X_train
X_train.head()
# Out:
#               cp_type_trt_cp  cp_time_48  cp_time_72  cp_dose_D2  g-0_scaled  \
# sig_id
# id_848dcc064               1           1           0           0    0.278145
# id_b9ce40651               1           0           0           0    0.301602
# id_a23c124dd               1           0           0           1    0.351926
# id_632f29352               1           0           0           0    0.331621
# id_db60af3c3               1           1           0           1    0.309449
#
#               g-1_scaled  g-2_scaled  g-3_scaled  g-4_scaled  g-5_scaled  ...  \
# sig_id                                                                    ...
# id_848dcc064    0.438289    0.514682    0.429166    0.409585    0.569830  ...
# id_b9ce40651    0.460960    0.464432    0.374016    0.356350    0.544769  ...
# id_a23c124dd    0.524016    0.515898    0.409870    0.399615    0.623608  ...
# id_632f29352    0.518773    0.543719    0.407282    0.320056    0.651487  ...
# id_db60af3c3    0.436247    0.496584    0.438492    0.354072    0.583075  ...
#
#               c-90_scaled  c-91_scaled  c-92_scaled  c-93_scaled  c-94_scaled  \
# sig_id
# id_848dcc064     0.752996     0.778936     0.714310     0.794292     0.723889
# id_b9ce40651     0.727436     0.733129     0.694349     0.748580     0.764400
# id_a23c124dd     0.752918     0.791095     0.706096     0.776449     0.661817
# id_632f29352     0.738325     0.794703     0.587779     0.808650     0.703848
# id_db60af3c3     0.823442     0.733865     0.788246     0.732076     0.736910
#
#               c-95_scaled  c-96_scaled  c-97_scaled  c-98_scaled  c-99_scaled
# sig_id
# id_848dcc064     0.851225     0.749730     0.849285     0.781899     0.784009
# id_b9ce40651     0.743710     0.776720     0.833604     0.806951     0.805640
# id_a23c124dd     0.778625     0.821844     0.809407     0.714703     0.618445
# id_632f29352     0.811472     0.791514     0.774037     0.719991     0.771593
# id_db60af3c3     0.825784     0.760141     0.882725     0.826118     0.813803
#
# [5 rows x 876 columns]

# %%
# Take a look at X_train
y_train.head()
# Out:
# sig_id
# id_848dcc064    0
# id_b9ce40651    0
# id_a23c124dd    0
# id_632f29352    0
# id_db60af3c3    0
# Name: cyclooxygenase_inhibitor, dtype: int64

# %%
# Baseline accuracy
y_train.value_counts(normalize=True) # baseline accuracy 0.982 ? too high
# Out:
# 0    0.981744
# 1    0.018256
# Name: cyclooxygenase_inhibitor, dtype: float64

# %%
eval_df = pd.DataFrame(columns = ['model_type', 'data_type', 'accuracy', 'precision', 'recall'])
eval_df
# Out:
# Empty DataFrame
# Columns: [model_type, data_type, accuracy, precision, recall]
# Index: []

# %%
# Logistic Regression

lr = LogisticRegression(C=1, random_state=123)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_train)

d = model.estimator_report('Logistic Regression', 'train', y_train, y_pred)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision  recall
# 0  Logistic Regression     train  0.981744        NaN     0.0

# %%
# Decision Tree

clf = DecisionTreeClassifier(max_depth=5, random_state=123)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_train)

d = model.estimator_report('Decision Tree', 'train', y_train, y_pred)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036        1.0  0.015974

# %%
# Random Forest

rf = RandomForestClassifier(n_estimators=100, 
                            max_depth=3, 
                            min_samples_split=2, 
                            min_samples_leaf=5, 
                            random_state=123)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_train)

d = model.estimator_report('Random Forest', 'train', y_train, y_pred)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036        1.0  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000

# %%
# Linear SVM

clf = SVC(kernel="linear", C=0.025)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_train)

d = model.estimator_report('Linear SVM', 'train',y_train, y_pred)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036        1.0  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000

# %%
# RBF SVM  

clf = SVC(gamma=2, C=1, random_state=123)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_train) # Took about 22 mins. 

d = model.estimator_report('RBF SVM', 'train', y_train, y_pred)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036        1.0  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000
# 4              RBF SVM     train  0.999825        1.0  0.990415

# %%
# Print out the confusion matrx for RBF SVM
confusion_matrix(y_train, y_pred)
# Out:
# array([[16832,     0],
#        [    3,   310]])

# %%
# AdaBoostCalssifier

abc = AdaBoostClassifier(random_state=123)
abc.fit(X_train, y_train)
y_pred_abc = abc.predict(X_train) # Took 1.5 mins

d = model.estimator_report('AdaBoost', 'train', y_train, y_pred_abc)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036   1.000000  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000
# 4              RBF SVM     train  0.999825   1.000000  0.990415
# 5             AdaBoost     train  0.981336   0.111111  0.003195

# %%
# Print out the confusion matrx for RBF SVM
confusion_matrix(y_train, y_pred_abc)
# Out:
# array([[16824,     8],
#        [  312,     1]])

# %%
# Naive Bayes

nb =  GaussianNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_train)

d = model.estimator_report('Naive Bayes', 'train', y_train, y_pred_nb)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036   1.000000  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000
# 4              RBF SVM     train  0.999825   1.000000  0.990415
# 5             AdaBoost     train  0.981336   0.111111  0.003195
# 6          Naive Bayes     train  0.280548   0.024220  0.977636

# %%
# Print out the confusion matrx for Naive Bayes
confusion_matrix(y_train, y_pred_nb)
# Out:
# array([[ 4504, 12328],
#        [    7,   306]])

# %%
# QDA

qda =  QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train)
y_pred_qda = qda.predict(X_train)

d = model.estimator_report('QDA', 'train', y_train, y_pred_qda)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036   1.000000  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000
# 4              RBF SVM     train  0.999825   1.000000  0.990415
# 5             AdaBoost     train  0.981336   0.111111  0.003195
# 6          Naive Bayes     train  0.280548   0.024220  0.977636
# 7                  QDA     train  0.981744        NaN  0.000000

# %%
# Print out the confusion matrx for QDA
confusion_matrix(y_train, y_pred_qda)
# Out:
# array([[16832,     0],
#        [  313,     0]])

# %%
# KNN

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_train) # Took 8 mins.

d = model.estimator_report('KNN', 'train', y_train, y_pred_knn)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036   1.000000  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000
# 4              RBF SVM     train  0.999825   1.000000  0.990415
# 5             AdaBoost     train  0.981336   0.111111  0.003195
# 6          Naive Bayes     train  0.280548   0.024220  0.977636
# 7                  QDA     train  0.981744        NaN  0.000000
# 8                  KNN     train  0.982910   0.812500  0.083067

# %%
# Print out the confusion matrx for KNN
confusion_matrix(y_train, y_pred_knn)
# Out:
# array([[16826,     6],
#        [  287,    26]])

# %%
# Neutal Net

mlp = MLPClassifier(random_state=123)
mlp.fit(X_train, y_train)
y_pred_mlp = mlp.predict(X_train)

d = model.estimator_report('Neural Net', 'train', y_train, y_pred_mlp)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#             model_type data_type  accuracy  precision    recall
# 0  Logistic Regression     train  0.981744        NaN  0.000000
# 1        Decision Tree     train  0.982036   1.000000  0.015974
# 2        Random Forest     train  0.981744        NaN  0.000000
# 3           Linear SVM     train  0.981744        NaN  0.000000
# 4              RBF SVM     train  0.999825   1.000000  0.990415
# 5             AdaBoost     train  0.981336   0.111111  0.003195
# 6          Naive Bayes     train  0.280548   0.024220  0.977636
# 7                  QDA     train  0.981744        NaN  0.000000
# 8                  KNN     train  0.982910   0.812500  0.083067
# 9           Neural Net     train  0.981744        NaN  0.000000

# %%
# Print out the confusion matrx for Neutral Net
confusion_matrix(y_train, y_pred_mlp)
# Out:
# array([[16832,     0],
#        [  313,     0]])

# %%
# Neutal Net-2

mlp2 = MLPClassifier(alpha=1, random_state=123)
mlp2.fit(X_train, y_train)
y_pred_mlp2 = mlp2.predict(X_train)

d = model.estimator_report('Neural Net-2', 'train', y_train, y_pred_mlp2)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
#              model_type data_type  accuracy  precision    recall
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 1         Decision Tree     train  0.982036   1.000000  0.015974
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 4               RBF SVM     train  0.999825   1.000000  0.990415
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548   0.024220  0.977636
# 7                   QDA     train  0.981744        NaN  0.000000
# 8                   KNN     train  0.982910   0.812500  0.083067
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000

# %%
# Print out the confusion matrx for Neutral Net-2
confusion_matrix(y_train, y_pred_mlp2)
# Out:
# array([[16832,     0],
#        [  313,     0]])

# %%
# Add baseline to the final eval
# Compute the y_pred for baseline

y_pred_b = [0]*y_train.shape[0]

# Compute the metrics for baseline
d = model.estimator_report('baseline', 'train', y_train, y_pred_b)

# Drop key data type
d = {'model_type': 'baseline',
     'accuracy': 0.9817439486730826,
     'precision': 'nan',
     'recall': 0.0}

# Append d to eval_final
eval_df = eval_df.append(d, ignore_index=True)

# Print eval_final
eval_df
# Out:
#              model_type data_type  accuracy  precision    recall
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 1         Decision Tree     train  0.982036          1  0.015974
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 4               RBF SVM     train  0.999825          1  0.990415
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548  0.0242204  0.977636
# 7                   QDA     train  0.981744        NaN  0.000000
# 8                   KNN     train  0.982910     0.8125  0.083067
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000
# 11             baseline       NaN  0.981744        nan  0.000000

# %%
# Fill baseline roll data type with 'train'
eval_df.iloc[11,1] = 'train'
eval_df
# Out:
#              model_type data_type  accuracy  precision    recall
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 1         Decision Tree     train  0.982036          1  0.015974
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 4               RBF SVM     train  0.999825          1  0.990415
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548  0.0242204  0.977636
# 7                   QDA     train  0.981744        NaN  0.000000
# 8                   KNN     train  0.982910     0.8125  0.083067
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000
# 11             baseline     train  0.981744        nan  0.000000

# %%
# Rank by accuracy
eval_df.sort_values(by='accuracy', ascending=False)
# Out:
#              model_type data_type  accuracy  precision    recall
# 4               RBF SVM     train  0.999825          1  0.990415
# 8                   KNN     train  0.982910     0.8125  0.083067
# 1         Decision Tree     train  0.982036          1  0.015974
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 7                   QDA     train  0.981744        NaN  0.000000
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000
# 11             baseline     train  0.981744        nan  0.000000
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548  0.0242204  0.977636

# %% [markdown]
# ### Select top model on validate and Test

# %%
# RBF SVM on validate (took 1.5 min)

# Confirm classifier
print(clf)

# Make prediction
y_pred_v = clf.predict(X_validate)
d = model.estimator_report('RBF SVM', 'validate', y_validate, y_pred_v)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=2, kernel='rbf', max_iter=-1,
#     probability=False, random_state=123, shrinking=True, tol=0.001,
#     verbose=False)
#              model_type data_type  accuracy  precision    recall
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 1         Decision Tree     train  0.982036          1  0.015974
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 4               RBF SVM     train  0.999825          1  0.990415
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548  0.0242204  0.977636
# 7                   QDA     train  0.981744        NaN  0.000000
# 8                   KNN     train  0.982910     0.8125  0.083067
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000
# 11             baseline     train  0.981744        nan  0.000000
# 12              RBF SVM  validate  0.981805        NaN  0.000000

# %%
# Print the confusion matrix for RBF SVM
confusion_matrix(y_validate, y_pred_v)
# Out:
# array([[4209,    0],
#        [  78,    0]])

# %%
# RBF SVM on test

# Confirm classifier
print(clf)

# Make prediction
y_pred_t = clf.predict(X_test)
d = model.estimator_report('RBF SVM', 'test', y_test, y_pred_t)
eval_df = eval_df.append(d, ignore_index=True)
eval_df
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=2, kernel='rbf', max_iter=-1,
#     probability=False, random_state=123, shrinking=True, tol=0.001,
#     verbose=False)
#              model_type data_type  accuracy  precision    recall
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 1         Decision Tree     train  0.982036          1  0.015974
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 4               RBF SVM     train  0.999825          1  0.990415
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548  0.0242204  0.977636
# 7                   QDA     train  0.981744        NaN  0.000000
# 8                   KNN     train  0.982910     0.8125  0.083067
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000
# 11             baseline     train  0.981744        nan  0.000000
# 12              RBF SVM  validate  0.981805        NaN  0.000000
# 13              RBF SVM      test  0.981528        NaN  0.000000

# %%
# Print the confusion matrix for RBF SVM
confusion_matrix(y_test, y_pred_t)
# Out:
# array([[2338,    0],
#        [  44,    0]])

# %%
# Rank by accuracy
eval_df.sort_values(by='accuracy', ascending=False)
# Out:
#              model_type data_type  accuracy  precision    recall
# 4               RBF SVM     train  0.999825          1  0.990415
# 8                   KNN     train  0.982910     0.8125  0.083067
# 1         Decision Tree     train  0.982036          1  0.015974
# 12              RBF SVM  validate  0.981805        NaN  0.000000
# 0   Logistic Regression     train  0.981744        NaN  0.000000
# 2         Random Forest     train  0.981744        NaN  0.000000
# 3            Linear SVM     train  0.981744        NaN  0.000000
# 7                   QDA     train  0.981744        NaN  0.000000
# 9            Neural Net     train  0.981744        NaN  0.000000
# 10         Neural Net-2     train  0.981744        NaN  0.000000
# 11             baseline     train  0.981744        nan  0.000000
# 13              RBF SVM      test  0.981528        NaN  0.000000
# 5              AdaBoost     train  0.981336   0.111111  0.003195
# 6           Naive Bayes     train  0.280548  0.0242204  0.977636

# %%
# eval_df.to_csv('evalute_model_cyclooxygenase_inhibitor.csv')

# %% [markdown]
# **Results and Conclusions**
# 1. 11 models have been trained to predict cyclooxygenase inhibitor. Recall and precision are used as the metrics.
#     - 6 of them perform the same as the baseline:
#         - LR
#         - Random Forest
#         - Linear SVM
#         - QDA
#         - Neural Net
#         - Neural Net-2
#     - 2 of them perform worse than the baseline:
#         - AdaBoost
#         - Naive Bayes
#     - 2 of them perform slightly better than the baseline:
#         - KNN
#         - Decision Tree
#     - The best model on train is RBF SVM.
# 2. However, the RBF SVM has overfitting issues when applying on valiate and test. Such pattern is observed when it was used to predict nfkb inhibitor.
